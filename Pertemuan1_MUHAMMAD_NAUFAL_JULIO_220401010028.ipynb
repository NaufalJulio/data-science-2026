# %% [markdown]
# <a href="https://colab.research.google.com/github/NaufalJulio/data-science-2026/blob/main/Pertemuan1_MUHAMMAD_NAUFAL_JULIO_220401010028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### PERTEMUAN 1 Data Science

# %% [markdown]
# MUHAMMAD NAUFAL JULIO | 220401010028 | IF405

# %% [markdown]
# Python — Notebook Pertama

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ===============================================

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Naufal Julio" # String
prodi = "Sains Data" # String
angkatan = 2022 # Integer
ipk = 3.75 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"prodi : {prodi}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Naufal Julio
# prodi : Sains Data
# Angkatan: 2022
# IPK : 3.75
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

# %%
hasil = perkenalan(nama, prodi, angkatan)
print(hasil)
# Out:
# Hai! Saya Naufal Julio dari Sains Data, angkatan 2022.
